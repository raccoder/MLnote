# %%
import numpy as np
class LinearRegression:
    def __init__(self):
        self.a = None
        self.b = None
    def fit(self,X,y):
        X = np.array(X)
        y = np.array(y)
        X_mean = np.mean(X)
        y_mean = np.mean(y)
        X_var  = np.mean(X*X) - (X_mean**2)
        Xy_cov = np.mean(X*y) - (X_mean*y_mean)
        self.a =  Xy_cov / X_var
        self.b = y_mean - self.a*X_mean
    def predict(self,X):
        return self.b + self.a*np.array(X)
    def coefficients(self):
        return (self.a, self.b)

# %%
# 決定係数 R^2 の計算
y_pred_train = model.predict(x)  # トレーニングデータに対する予測値
ss_res = np.sum((y - y_pred_train) ** 2)
ss_tot = np.sum((y - np.mean(y)) ** 2)
r2_score = 1 - (ss_res / ss_tot)

print(f"R^2 Score: {r2_score}")

# 予測値と実際の値のプロット
plt.scatter(x, y, color='blue', label='Actual values')
plt.scatter(x, y_pred_train, color='red', label='Predicted values', alpha=0.5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()
# Out:
# R^2 Score: 0.7272727272727273
